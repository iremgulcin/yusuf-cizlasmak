# %%
# !pip install ultralytics wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 20.2 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import settings
settings.update({"wandb": True})
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import wandb
wandb.login(key="1f27e68cbbace45cf309502835d1f46fcd730f09")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ycizlasmak (ycizlasmak-sakarya-applied-science-university). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from ultralytics import YOLO

# Modeli yükle
model = YOLO("yolo11s.pt")

# Eğitim işlemi
train_results = model.train(
    data="/kaggle/input/data-yaml/data.yaml",  # Veri kümesi için YAML dosyası
    epochs=50,  # Eğitim epoch sayısı
    imgsz=512,  # Görüntü boyutu
    device="0",  # GPU cihazını seç
    verbose=True,
    project="/kaggle/working/YOLOv11-Kaggle",  # Proje klasörü
    name="first_model",  # Deney adı
    workers=2,  # DataLoader işçi sayısı
    save_period=1  # Her epoch sonrası modelin kaydedilmesi
)


# W&B oturumunu sonlandır
wandb.finish()
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 224MB/s]
# Ultralytics 8.3.66 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Modeli yükle
model = YOLO("/kaggle/input/dummy-model-1/dummy_model_1.pt")  # Eğitilmiş modeli yükle

# Validation veri kümesini test et
val_results = model.val(
    data="/kaggle/input/data-yaml/data.yaml",  # Veri kümesi YAML dosyası
    split="val",  # Val seti üzerinde çalış
    imgsz=512,  # Görüntü boyutu
    device="0",  # GPU cihazını seç
    verbose=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.67 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 25.1MB/s]
# val: Scanning /kaggle/input/pothole-dataset-2/pothole_dataset_2/valid... 1808 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1808/1808 [00:08<00:00, 220.57it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/pothole-dataset-2/pothole_dataset_2 is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 113/113 [00:15<00:00,  7.44it/s]
# ...

# %%
from ultralytics import YOLO
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Modeli yükle
model = YOLO("/kaggle/input/medium-model/medium_model.pt")  # Eğitilmiş modeli yükle

# Validation veri kümesini test et
val_results = model.val(
    data="/kaggle/input/data-yaml/data.yaml",  # Veri kümesi YAML dosyası
    split="val",  # Val seti üzerinde çalış
    imgsz=512,  # Görüntü boyutu
    device="0",  # GPU cihazını seç
    verbose=True
)
# Out:
# Ultralytics 8.3.67 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /kaggle/input/pothole-dataset-2/pothole_dataset_2/valid... 1808 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1808/1808 [00:02<00:00, 867.22it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/pothole-dataset-2/pothole_dataset_2 is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 113/113 [00:14<00:00,  7.80it/s]
#                    all       1808       4487       0.92      0.852      0.929      0.704
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.10/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# ...
